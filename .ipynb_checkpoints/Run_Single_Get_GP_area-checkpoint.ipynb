# %% [markdown]
# This file is taken from Peter Yoachim github at https://github.com/yoachim/20_Scratch/blob/master/maf_examples/read_example.ipynb

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import healpy as hp

import lsst.sims.maf.db as db
import lsst.sims.maf.utils as utils
import lsst.sims.maf.metrics as metrics
import lsst.sims.maf.slicers as slicers
import lsst.sims.maf.stackers as stackers
import lsst.sims.maf.metricBundles as metricBundles

# %%
# Connect to any old simulation

dbDir = '/home/idies/workspace/lsst_cadence/FBS_1.5/'

dbFile = dbDir+'baseline_v1.5_10yrs.db'
conn = db.OpsimDatabase(dbFile)
your_username = 'somayeh91'
outDir = '/home/idies/workspace/Storage/{}/persistent/MAFOutput/run_single_metrics/'.format(your_username)
resultsDb = db.ResultsDb(outDir=outDir)

# %%
# Let's compute the coadded depth on the whole sky, and then the median
bundleList = []
sql = 'filter="r"'
metric = metrics.UniformityMetric()
slicer = slicers.HealpixSlicer()
summaryStats = [metrics.MedianMetric()]
# plotDict = {'colorMax': 27.4}
bundleList.append(metricBundles.MetricBundle(metric,slicer,sql, summaryMetrics=summaryStats))#, plotDict=plotDict

bd = metricBundles.makeBundlesDictFromList(bundleList)
bg = metricBundles.MetricBundleGroup(bd, conn, outDir=outDir, resultsDb=resultsDb)
bg.runAll()
# Out:
# Healpix slicer using NSIDE=128, approximate resolution 27.483891 arcminutes
# Querying database SummaryAllProps with constraint filter="r" for columns ['observationStartMJD', 'fieldDec', 'fieldRA']
# Found 491676 visits
# Running:  ['opsim_Uniformity_observationStartMJD_r_HEAL']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.

# %%
bg.plotAll(closefigs=False)
# Out:
# Plotting figures with "filter="r"" constraint now.
# /home/idies/lsst/stack/miniconda3-4.7.10-4d7b902/Linux64/sims_maf/2.13.0.sims-24-gbe21ed04+1/python/lsst/sims/maf/utils/mafUtils.py:58: UserWarning: Optimal bin calculation tried to make 778 bins, returning 200
#   warnings.warn('Optimal bin calculation tried to make %.0f bins, returning %i'%(nbins, nbinMax))
# monopole: 0.0955837  dipole: lon: -108.49, lat: 38.8891, amp: 0.0260105
# Plotting complete.

# %%
# If we look in the read_example directory, there's a .npz file with the results, and a resultsDb_sqlite.db 
# file that should should have the summary stats in there

# %%
ack = np.load(outDir+'opsim_Uniformity_observationStartMJD_r_HEAL.npz', allow_pickle=True)

# %%
list(ack.keys())
# Out:
# ['header',
#  'metricValues',
#  'mask',
#  'fill',
#  'slicer_init',
#  'slicerName',
#  'slicePoints',
#  'slicerNSlice',
#  'slicerShape']

# %%
# Oh right, the output maps are numpy masked arrays, but the numpy save feature only supports regular arrays,
# so that's why this is a little messy.

# %%
#
ack['metricValues']
# Out:
# array([6.93247034e-310, 4.68091458e-310, 4.68091575e-310, ...,
#        1.79757375e-001, 2.11645865e-001, 1.66392865e-001])

# %%
hp.mollview(ack['metricValues'],min = 0)

# %%
# To really make it like it was before
import numpy.ma as ma

metricValues = ma.MaskedArray(data=ack['metricValues'],mask=ack['mask'],fill_value=ack['fill'])

# %%
# Now points on the sky where there were no observations are masked and filled to the healpy unseen value
hp.mollview(metricValues)

# %%
# now let's pull out the summary stat that we saved
import sqlite3
import pandas as pd

con = sqlite3.connect('read_example/resultsDb_sqlite.db')
# Here's a complicated sql query to pull out the data. The idea is we can support running lots of different 
# metrics and summary stats all in one big database, but it looks a little silly when there's just one value in there
query  = 'select summaryValue from summarystats where summaryName="Median" and metricId=(select metricId from metrics where metricName="Uniformity")'

df = pd.read_sql(query, con)

# %%
df
# Out:
# Empty DataFrame
# Columns: [summaryValue]
# Index: []
